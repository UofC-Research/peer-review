# %%
#installation of packages needed for project
# !pip install schemdraw
# !pip install metapub
# !pip install pymed
#!pip install pymupdf
# !pip install openparse
# !pip install tqdm
# !pip install readerwriterlock
# !pip install sortedcontainers
# !pip install pyspark
# !pip install python-doi
# !pip install pyspark
# Out:
# Collecting schemdraw
#   Downloading schemdraw-0.20-py3-none-any.whl.metadata (2.2 kB)
# Downloading schemdraw-0.20-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: schemdraw
# Successfully installed schemdraw-0.20
# Collecting metapub
#   Downloading metapub-0.5.12-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from metapub) (75.1.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from metapub) (5.3.1)
# Collecting lxml-html-clean (from metapub)
#   Downloading lxml_html_clean-0.4.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from metapub) (2.32.3)
# Collecting eutils (from metapub)
#   Downloading eutils-0.6.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting habanero (from metapub)
#   Downloading habanero-2.2.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from metapub) (0.9.0)
# Collecting cssselect (from metapub)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting unidecode (from metapub)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Collecting docopt (from metapub)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from metapub) (1.17.0)
# Collecting coloredlogs (from metapub)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting python-Levenshtein (from metapub)
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->metapub)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from eutils->metapub) (2025.1)
# Requirement already satisfied: httpx>=0.27.2 in /usr/local/lib/python3.11/dist-packages (from habanero->metapub) (0.28.1)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.11/dist-packages (from habanero->metapub) (24.2)
# Requirement already satisfied: pyyaml>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from habanero->metapub) (6.0.2)
# Requirement already satisfied: tqdm>=4.66.5 in /usr/local/lib/python3.11/dist-packages (from habanero->metapub) (4.67.1)
# Collecting urllib3==2.2.0 (from habanero->metapub)
#   Downloading urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting Levenshtein==0.27.1 (from python-Levenshtein->metapub)
#   Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-Levenshtein->metapub)
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->metapub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->metapub) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->metapub) (2025.1.31)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.2->habanero->metapub) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.2->habanero->metapub) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.2->habanero->metapub) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.2->habanero->metapub) (1.3.1)
# Downloading metapub-0.5.12-py2.py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.4/147.4 kB 7.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.3 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading eutils-0.6.0-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.3 MB/s eta 0:00:00
# Downloading habanero-2.2.0-py3-none-any.whl (28 kB)
# Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 kB 6.1 MB/s eta 0:00:00
# Downloading lxml_html_clean-0.4.1-py3-none-any.whl (14 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 9.6 MB/s eta 0:00:00
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 13.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.2 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 49.4 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=2ba8af7735801a4f17f1c80551b7ba01c1ed47bde7c05a2af77e1551282b1225
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: docopt, urllib3, unidecode, rapidfuzz, lxml-html-clean, humanfriendly, cssselect, Levenshtein, coloredlogs, python-Levenshtein, habanero, eutils, metapub
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
# Successfully installed Levenshtein-0.27.1 coloredlogs-15.0.1 cssselect-1.3.0 docopt-0.6.2 eutils-0.6.0 habanero-2.2.0 humanfriendly-10.0 lxml-html-clean-0.4.1 metapub-0.5.12 python-Levenshtein-0.27.1 rapidfuzz-3.12.2 unidecode-1.3.8 urllib3-2.2.0
# Collecting pymed
#   Downloading pymed-0.8.9-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from pymed) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (2025.1.31)
# Downloading pymed-0.8.9-py3-none-any.whl (9.6 kB)
# Installing collected packages: pymed
# Successfully installed pymed-0.8.9
# Collecting openparse
#   Downloading openparse-0.7.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting PyMuPDF>=1.23.2 (from openparse)
#   Downloading pymupdf-1.25.4-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pillow>=8.3 in /usr/local/lib/python3.11/dist-packages (from openparse) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from openparse) (2.10.6)
# Collecting pypdf>=4.0.0 (from openparse)
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pdfminer.six>=20200401 (from openparse)
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Collecting tiktoken>=0.3 (from openparse)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: openai>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from openparse) (1.61.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from openparse) (2.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai>=1.0.0->openparse) (4.12.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six>=20200401->openparse) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six>=20200401->openparse) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->openparse) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->openparse) (2.27.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.3->openparse) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.3->openparse) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.0.0->openparse) (3.10)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six>=20200401->openparse) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.0.0->openparse) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.0.0->openparse) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0.0->openparse) (0.14.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.3->openparse) (2.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200401->openparse) (2.22)
# Downloading openparse-0.7.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 6.7 MB/s eta 0:00:00
# Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 89.4 MB/s eta 0:00:00
# Downloading pymupdf-1.25.4-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 77.3 MB/s eta 0:00:00
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 20.6 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.3 MB/s eta 0:00:00
# Installing collected packages: pypdf, PyMuPDF, tiktoken, pdfminer.six, openparse
# Successfully installed PyMuPDF-1.25.4 openparse-0.7.0 pdfminer.six-20240706 pypdf-5.4.0 tiktoken-0.9.0
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting readerwriterlock
#   Downloading readerwriterlock-1.0.9-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from readerwriterlock) (4.12.2)
# Downloading readerwriterlock-1.0.9-py3-none-any.whl (10.0 kB)
# Installing collected packages: readerwriterlock
# Successfully installed readerwriterlock-1.0.9
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (2.4.0)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)
# Collecting python-doi
#   Downloading python-doi-0.2.0.tar.gz (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.9/245.9 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-doi
#   Building wheel for python-doi (setup.py) ... done
#   Created wheel for python-doi: filename=python_doi-0.2.0-py2.py3-none-any.whl size=5163 sha256=2eccb17672001e28a6d6683be5bc66b700233793c33dd4757745f7f25108c09a
#   Stored in directory: /root/.cache/pip/wheels/ac/79/30/9861968b82780641eb0912d9f070df5a5fca3489d9bf101319
# Successfully built python-doi
# Installing collected packages: python-doi
# Successfully installed python-doi-0.2.0
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# ## Clone Github repository

# %%
import pprint
import sys

#!git clone https://github.com/UofC-Research/peer-review.git
# !git clone https://github.com/jlee2843/Peer-Review-22-23.git
# %cd Peer-Review-22-23
# !git checkout Albert-2022

sys.path.append('/content/Peer-Review-22-23/')
# Out:
# Cloning into 'Peer-Review-22-23'...
# remote: Enumerating objects: 1488, done.
# remote: Counting objects: 100% (325/325), done.
# remote: Compressing objects: 100% (202/202), done.
# remote: Total 1488 (delta 208), reused 230 (delta 122), pack-reused 1163 (from 1)
# Receiving objects: 100% (1488/1488), 5.95 MiB | 15.66 MiB/s, done.
# Resolving deltas: 100% (1034/1034), done.
# /content/Peer-Review-22-23
# Branch 'Albert-2022' set up to track remote branch 'Albert-2022' from 'origin'.
# Switched to a new branch 'Albert-2022'

# %% [markdown]
# ### Pull modified modules from Github

# %%
pprint.pprint(sys.path)
# %cd /content/Peer-Review-22-23/
# !git pull
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '',
#  '/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.11/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/Peer-Review-22-23/',
#  '/content/Peer-Review-22-23/',
#  '/content/Peer-Review-22-23/',
#  '/content/Peer-Review-22-23/',
#  '/content/Peer-Review-22-23/']
# /content/Peer-Review-22-23
# Already up to date.

# %% [markdown]
# ## Case \#1: Pre-publish Data query for given timeframe

# %%
# "global" variables
base_url: str = 'https://api.biorxiv.org'
query_type: str = 'details'
server: str = 'biorxiv'
start_interval: str = '2011-01-01'
end_interval: str = '2020-12-31'
step = 100

# %% [markdown]
# ### BioRvix Server

# %%
# "local" variables
url: str = f'{base_url}/{query_type}/{server}/{start_interval}/{end_interval}'
path: str = f'prepub-{query_type}-{server}-{start_interval}!{end_interval}-{datetime.now()}'
step = 100
journal_df = None

#finding the number of records for a given time period
#tmp = f"{base_url}/{start_interval}/{end_interval}"
#tmp = 'https://api.biorxiv.org/details/biorxiv/2020-08-21/2020-08-28'

#create directory
pathlib.Path(path).mkdir(parents=True, exist_ok=True)

multithread_processor(path, url,
                      ["doi", "title", "authors", "author_corresponding", "author_corresponding_institution", "date",
                       "version", "type", "category", "jatsxml", "published"],
                      ["DOI", "Title", "Authors", "Corresponding_Authors", "Institution", "Date", "Version", "Type",
                       "Category", "Xml", "Published"],
                      step, range(0, get_total(url), step), True)
# Out:
# values: [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700, 10800, 10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800, 11900, 12000, 12100, 12200, 12300, 12400, 12500, 12600, 12700, 12800, 12900, 13000, 13100, 13200, 13300, 13400, 13500, 13600, 13700, 13800, 13900, 14000, 14100, 14200, 14300, 14400, 14500, 14600, 14700, 14800, 14900, 15000, 15100, 15200, 15300, 15400, 15500, 15600, 15700, 15800, 15900, 16000, 16100, 16200, 16300, 16400, 16500, 16600, 16700, 16800, 16900, 17000, 17100, 17200, 17300, 17400, 17500, 17600, 17700, 17800, 17900, 18000, 18100, 18200, 18300, 18400, 18500, 18600, 18700, 18800, 18900, 19000, 19100, 19200, 19300, 19400, 19500, 19600, 19700, 19800, 19900, 20000, 20100, 20200, 20300, 20400, 20500, 20600, 20700, 20800, 20900, 21000, 21100, 21200, 21300, 21400, 21500, 21600, 21700, 21800, 21900, 22000, 22100, 22200, 22300, 22400, 22500, 22600, 22700, 22800, 22900, 23000, 23100, 23200, 23300, 23400, 23500, 23600, 23700, 23800, 23900, 24000, 24100, 24200, 24300, 24400, 24500, 24600, 24700, 24800, 24900, 25000, 25100, 25200, 25300, 25400, 25500, 25600, 25700, 25800, 25900, 26000, 26100, 26200, 26300, 26400, 26500, 26600, 26700, 26800, 26900, 27000, 27100, 27200, 27300, 27400, 27500, 27600, 27700, 27800, 27900, 28000, 28100, 28200, 28300, 28400, 28500, 28600, 28700, 28800, 28900, 29000, 29100, 29200, 29300, 29400, 29500, 29600, 29700, 29800, 29900, 30000, 30100, 30200, 30300, 30400, 30500, 30600, 30700, 30800, 30900, 31000, 31100, 31200, 31300, 31400, 31500, 31600, 31700, 31800, 31900, 32000, 32100, 32200, 32300, 32400, 32500, 32600, 32700, 32800, 32900, 33000, 33100, 33200, 33300, 33400, 33500, 33600, 33700, 33800, 33900, 34000, 34100, 34200, 34300, 34400, 34500, 34600, 34700, 34800, 34900, 35000, 35100, 35200, 35300, 35400, 35500, 35600, 35700, 35800, 35900, 36000, 36100, 36200, 36300, 36400, 36500, 36600, 36700, 36800, 36900, 37000, 37100, 37200, 37300, 37400, 37500, 37600, 37700, 37800, 37900, 38000, 38100, 38200, 38300, 38400, 38500, 38600, 38700, 38800, 38900, 39000, 39100, 39200, 39300, 39400, 39500, 39600, 39700, 39800, 39900, 40000, 40100, 40200, 40300, 40400, 40500, 40600, 40700, 40800, 40900, 41000, 41100, 41200, 41300, 41400, 41500, 41600, 41700, 41800, 41900, 42000, 42100, 42200, 42300, 42400, 42500, 42600, 42700, 42800, 42900, 43000, 43100, 43200, 43300, 43400, 43500, 43600, 43700, 43800, 43900, 44000, 44100, 44200, 44300, 44400, 44500, 44600, 44700, 44800, 44900, 45000, 45100, 45200, 45300, 45400, 45500, 45600, 45700, 45800, 45900, 46000, 46100, 46200, 46300, 46400, 46500, 46600, 46700, 46800, 46900, 47000, 47100, 47200, 47300, 47400, 47500, 47600, 47700, 47800, 47900, 48000, 48100, 48200, 48300, 48400, 48500, 48600, 48700, 48800, 48900, 49000, 49100, 49200, 49300, 49400, 49500, 49600, 49700, 49800, 49900, 50000, 50100, 50200, 50300, 50400, 50500, 50600, 50700, 50800, 50900, 51000, 51100, 51200, 51300, 51400, 51500, 51600, 51700, 51800, 51900, 52000, 52100, 52200, 52300, 52400, 52500, 52600, 52700, 52800, 52900, 53000, 53100, 53200, 53300, 53400, 53500, 53600, 53700, 53800, 53900, 54000, 54100, 54200, 54300, 54400, 54500, 54600, 54700, 54800, 54900, 55000, 55100, 55200, 55300, 55400, 55500, 55600, 55700, 55800, 55900, 56000, 56100, 56200, 56300, 56400, 56500, 56600, 56700, 56800, 56900, 57000, 57100, 57200, 57300, 57400, 57500, 57600, 57700, 57800, 57900, 58000, 58100, 58200, 58300, 58400, 58500, 5 ...
# args: 1481
# [('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 0, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 100, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 200, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 300, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 400, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 500, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 600, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 700, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 20:08:49.195096', 'https://api.biorxiv.org/details/biorxiv/2011-01-01/2020-12-31', 800, ['doi', 'title', 'authors', 'author_corresponding', 'author_corresponding_institution', 'date', 'version', 'type', 'category', 'jatsxml', 'published'], ['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Date', 'Version', 'Type', 'Category', 'Xml', 'Published'], 100, True), ('prepub-details-biorxiv-2011-01-01!2020-12-31-2023-01-03 2 ...
# get_big_data:   0%|          | 0/1481 [00:00<?, ?it/s]

# %%
journal_df = pd.read_parquet(pathlib.Path(path))
journal_df = create_prepublish_df(journal_df)

display(journal_df)

# %%
pd.options.mode.use_inf_as_na = True  # this option check for empty strings as well
jl_fix_df = pd.DataFrame(columns=journal_df.columns)
for col in journal_df:
    jl_fix_df = pd.concat([jl_fix_df, journal_df[journal_df[col].isna()]])
    jl_fix_df = pd.concat([jl_fix_df, journal_df[journal_df[col] == '']])

display(jl_fix_df)

# %% [markdown]
# ### Publication data for Prepublication data for the given time period

# %%
#from tqdm import tqdm_notebook, tnrange

#variables
#https://api.biorxiv.org/pubs/biorvix/10.1101/759530
base_url: str = 'https://api.biorxiv.org'
query_type: str = 'pubs'
server: str = 'biorxiv'
url: str = f'{base_url}/{query_type}/{server}'
path: str = f'pub_journal-{query_type}-{server}-{datetime.now()}'
step = 100
#doi = ['10.1101/856302']
doi = journal_df[journal_df.Published != 'NA'].Published

#create directory
pathlib.Path(path).mkdir(parents=True, exist_ok=True)
total = len(doi)
#def process_doi_data(path:str, url:str, doi:pd.Series, meta: List, col_names: List, item:int, loop_list, disable:bool = False):

args = [(path, url, doi,
         ["preprint_doi", "published_doi", "preprint_title", "preprint_authors", "preprint_author_corresponding",
          "preprint_author_corresponding_institution", "preprint_category", "published_journal", "preprint_date",
          "published_date"],
         ["DOI", "pub_DOI", "Title", "Authors", "Corresponding_Authors", "Institution", "Category", "Journal",
          "Preprint_Date", "Published_Date"],
         item, True) for item in range(0, total, step)]
print(f'total doi: {total} iter: {total / step}')
tq.thread_map(lambda p: process_doi_data(*p), args, desc='process_doi_data', max_workers=5, total=len(args))
#tq.thread_map(lambda p: process_doi_data(*p), args, desc='process_doi_data', total=len(args))
# Out:
# total doi: 102771 iter: 1027.71
# process_doi_data:   0%|          | 0/1028 [00:00<?, ?it/s]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
filtered_df = pd.read_parquet(pathlib.Path(path))
print([item for item in filtered_df.Published_Date if len(item.strip()) != 10])
filtered_df = create_published_df(filtered_df).reindex()
filtered_df.rename(columns={'pub_DOI': 'Published', 'Preprint_Date': 'Date'}, inplace=True)
# Out:
# ['2017-11-3', '2017-12-4', '2017-12-4', '2017-11-9', '2017-11-8', '2017-11-8', '2017-11-8', '2018-08-30:e12744', '2017-12-6', '2017-12-6', '2017-12-8', '2018-05-15:1-12', '2018-03-21:1-11', '2018-05-15:fj2018002', '2018-11-28:1-14', '2018-11-28:1-14', '2018-02-6', '2018-05-1', '2018-10-24:mbcE18080', '2018-10-24:mbcE18080', '2018-10-24:mbcE18080', '2019-05-16:e1800100', '2019-05-14:1-8', '2019-07-4:1-9', '-00-00', '-00-00', '-00-00', '-00-00', '-00-00', '-00-00', '-00-00', '-00-00', '-00-00', '-00-00']
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'
# time data '-00-00' does not match format '%Y-%m-%d'

# %% [markdown]
# Finding and cleaning missing data

# %%
pd.options.mode.use_inf_as_na = True  # this option check for empty strings as well
fix_df = pd.DataFrame(columns=filtered_df.columns)
for col in filtered_df:
    fix_df = pd.concat([fix_df, filtered_df[filtered_df[col].isna()]])
    fix_df = pd.concat([fix_df, filtered_df[filtered_df[col] == '']])

display("Rows with incomplete data:", fix_df)
# Out:
# 'Rows with incomplete data:'
#                              DOI                     Published  \
# 13400             10.1101/092171       10.1109/MM.2019.2910009
# 13500             10.1101/092171       10.1109/MM.2019.2910009
# 16800             10.1101/104778    10.1038/s41598-017-04402-4
# 79400  10.1101/2020.01.16.908798  10.1371/journal.pone.0228429
# 92000  10.1101/2020.05.10.084335        10.1126/sciadv.abd2781
# ...                          ...                           ...
# 95900  10.1101/2020.06.18.159608    10.1038/s41467-021-22110-6
# 96000  10.1101/2020.06.18.159608    10.1038/s41467-021-22110-6
# 96100  10.1101/2020.06.18.159608    10.1038/s41467-021-22110-6
# 94100  10.1101/2020.08.28.273003            10.1002/glia.23946
# 98900  10.1101/2020.10.11.335232            10.1364/BOE.411898
#
#                                                    Title  \
# 13400  Darwin: A Hardware-acceleration Framework for ...
# 13500  Darwin: A Hardware-acceleration Framework for ...
# 16800  Engaging narratives evoke similar neural activ...
# 79400  Pterostilbene Protects Cochlea from Ototoxicit...
# 92000  Notch1 switches progenitor competence in induc...
# ...                                                  ...
# 95900  Structure of the complete, membrane-assembled ...
# 96000  Structure of the complete, membrane-assembled ...
# 96100  Structure of the complete, membrane-assembled ...
# 94100  A Novel Factor in Olfactory Ensheathing Cell-A...
# 98900  Light transport modeling in highly complex tis...
#
#                                                  Authors  \
# 13400  Turakhia, Y.; Zheng, K. J.; Bejerano, G.; Dall...
# 13500  Turakhia, Y.; Zheng, K. J.; Bejerano, G.; Dall...
# 16800              Cohen, S. S.; Henin, S.; Parra, L. C.
# 79400  ÖZDAS, S.; TASTEKIN, B.; GÜRGEN, S. G.; ÖZD...
# 92000                                         Tiberi, L.
# ...                                                  ...
# 95900  Hutchings, J.; Stancheva, V. G.; Brown, N. R.;...
# 96000  Hutchings, J.; Stancheva, V. G.; Brown, N. R.;...
# 96100  Hutchings, J.; Stancheva, V. G.; Brown, N. R.;...
# 94100                    Saglam, A.; Calof, A.; Wray, S.
# 98900                        Yan, S.; Yuan, Y.; Fang, Q.
#
#       Corresponding_Authors  \
# 13400
# 13500
# 16800
# 79400
# 92000
# ...                     ...
# 95900       Giulia  Zanetti
# 96000       Giulia  Zanetti
# 96100       Giulia  Zanetti
# 94100           Susan  Wray
# 98900        Qianqian  Fang
#
#                                              Institution        Category  \
# 13400                                STANFORD UNIVERSITY        Genomics
# 13500                                STANFORD UNIVERSITY        Genomics
# 16800  THE CITY COLLEGE OF THE CITY UNIVERSITY OF NEW...    Neuroscience
# 79400           HACETTEPE UNIVERSITY, FACULTY OF SCIENCE    Neuroscience
# 92000                               UNIVERSITY OF TRENTO  Cancer Biology
# ...                                                  ...             ...
# 95900                             ISMB, BIRKBECK COLLEGE    Cell Biology
# 96000                             ISMB, BIRKBECK COLLEGE    Cell Biology
# 96100                             ISMB, BIRKBECK COLLEGE    Cell Biology
# 94100                      NATIONAL INSTITUTES OF HEALTH    Neuroscience
# 98900                            NORTHEASTERN UNIVERSITY      Biophysics
#
#                   Journal       Date Published_Date Num_of_Authors
# 13400          Ieee Micro 2017-01-15     2019-04-11              4
# 13500          Ieee Micro 2017-01-15     2019-04-11              4
# 16800  Scientific Reports 2017-01-31     2017-07-04              3
# 79400            Plos One 2020-01-16     2020-07-28              8
# 92000    Science Advances 2020-05-10     2021-06-23              1
# ...                   ...        ...            ...            ...
# 95900                     2020-06-19            NaT              6
# 96000                     2020-06-19            NaT              6
# 96100                     2020-06-19            NaT              6
# 94100                     2020-08-28            NaT              3
# 98900                     2020-10-12            NaT              3
#
# [93 rows x 11 columns]

# %%
print(f'\nPrepublished Artices w/ Publication Info that have missing info: {filtered_df.isnull().sum()}\n')
#print('Published data:\n',[(name, journal_df[name].isnull().sum()) for name in journal_df.columns if journal_df[name].isnull().values.any()])
#print('Prepublish data:\n',[(name, filtered_df[name].isnull().sum()) for name in filtered_df.columns if filtered_df[name].isnull().values.any()])
fix_df = filtered_df[filtered_df['Published_Date'].isna()]
display("Rows with NaN:", fix_df)

# %%
filtered_df.info()
clean_df = filtered_df.dropna()
merged_df = pd.merge(journal_df, clean_df, how='right',
                     on=['DOI', 'Published', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Category',
                         'Date', 'Num_of_Authors'])

# %%
pd.options.mode.use_inf_as_na = True
print(f'Prepublished Artices w/ Publication Info: {merged_df.isnull().sum()}')
display(merged_df)

# %% [markdown]
# #### General Descriptive Anaylsis

# %%
#summary of table
journal_df.describe(include='all')

# %%
#freq count of Num_of_Authors
freq_count(journal_df, 'Num_of_Authors')

# %%
#freq count of Corresponding_Authors
freq_count(journal_df, 'Corresponding_Authors')

# %%
#freq count of Instituion
freq_count(journal_df, 'Institution')

# %%
#freq count of Date
freq_count(journal_df, 'Date')

# %%
#freq count of number of version
freq_count(journal_df, 'Version')

# %%
#freq count of Type
freq_count(journal_df, 'Type')

# %%
#freq count Category
freq_count(journal_df, 'Category')

# %% [markdown]
# #### Check

# %%
assert get_total(url) == journal_df.shape[0]
"Total number of papers submitted and the length of the dataframe match."

# %% [markdown]
# The above code runs through all papers that are submitted within selected time frame. Error discussed during the previous meeting has been fixed.

# %% [markdown]
# ----

# %% [markdown]
# ### Published Articles query for a given timefame

# %%
# "global" variables
#https://api.biorxiv.org/pubs/biorvix/2018-08-21/2018-08-28
base_url: str = 'https://api.biorxiv.org'
query_type: str = 'pubs'
server: str = 'biorxiv'
start_interval: str = '2011-01-01'
end_interval: str = '2020-12-31'

# %% [markdown]
# ### BioRvix Server

# %%
# "local" variables
url: str = f'{base_url}/{query_type}/{server}/{start_interval}/{end_interval}'
path: str = f'pub-{query_type}-{server}-{start_interval}!{end_interval}-{datetime.now()}'
step = 100
pubs_df = None

#finding the number of records for a given time period

pathlib.Path(path).mkdir(parents=True, exist_ok=True)
print(url)

multithread_processor(path, url,
                      ["preprint_doi", "published_doi", "preprint_title", "preprint_authors",
                       "preprint_author_corresponding", "preprint_author_corresponding_institution",
                       "preprint_category", "published_journal", "preprint_date", "published_date"],
                      ["DOI", "pub_DOI", "Title", "Authors", "Corresponding_Authors", "Institution", "Category",
                       "Journal", "Preprint_Date", "Published_Date"],
                      step, range(0, get_total(url), 100), True)

# %%
pubs_df = pd.read_parquet(pathlib.Path(path)).sort_index(kind='mergesort', key=lambda x: x.astype(int))

# %%
pubs_df.head(1)
#print([(index, value, datetime.strptime(value.split(':')[0], '%Y-%m-%d').date()) for index, value in enumerate(pubs_df.Published_Date) if len(value.strip()) != 10])
print([(index, value) for index, value in enumerate(pubs_df.Published_Date) if len(value.strip()) != 10])

# %%
pubs_df = create_published_df(pubs_df)

#display(pubs_df)
#pubs_df.shape

# %%
pubs_df.info()
print(pubs_df.Published_Date.isna().values.any(), pubs_df.Preprint_Date.isna().values.any())
print(pubs_df.Published_Date.subtract(pubs_df.Preprint_Date))
#for index in range(pubs_df.shape[0]):
#    try:
#        pubs_df.loc(index, 'Published_Date') - pubs_df.loc(index, 'Preprint_Date')
#    except Exception as e:
#print(e)
#print (f'index: {index} Published_Date: {')

# %% [markdown]
# #### General Descriptive Analysis

# %%
pubs_df.info()

# %%
#summary of table
pubs_df.describe(include='all')

# %%
#freq count of Num_of_Authors
freq_count(pubs_df, 'Num_of_Authors')

# %%
#freq count "Corresponding_Authors"
freq_count(pubs_df, 'Corresponding_Authors')

# %%
#freq_count Institution
freq_count(pubs_df, 'Institution')

# %%
#freq_count Category
freq_count(pubs_df, 'Category')

# %%
#freq count Jounral
freq_count(pubs_df, 'Journal')

# %%
#freq count Preprint_Date
freq_count(pubs_df, 'Preprint_Date')

# %%
#freq count Published_date
freq_count(pubs_df, 'Published_Date')

# %% [markdown]
# #### Check

# %%
'''
                      columns=["pre_DOI", "pub_DOI",
                               "Title", "Authors", "Corresponding_Authors",
                               "Institution",
                               "Category", "Journal", "Preprint_Date", "Published_Date"])
'''
#assert get_total(f'{base_url}{query_type}{server}{start_interval}{end_interval}') == pubs_df.shape[0]
"Total number of papers published and the length of the dataframe does match."

# %% [markdown]
# ----

# %% [markdown]
# ## Case \#2: Published articles query for a given timeframe

# %%
from multipledispatch import dispatch


@dispatch(pd.DataFrame, int, str)
def get_values(df: pd.DataFrame, row: int, col: str):
    return get_values(df, [row], [col])


@dispatch(pd.DataFrame, int, list)
def get_values(df: pd.DataFrame, row: int, cols: List[str]):
    return get_values(df, [row], cols)


@dispatch(pd.DataFrame, list, str)
def get_values(df: pd.DataFrame, rows: List[int], col: str):
    return get_values(df, rows, [col])


@dispatch(pd.DataFrame, list, list)
def get_values(df: pd.DataFrame, rows: List[int], cols: List[str]) -> List[List[str]]:
    return [[df.at(row, col) for col in cols] for row in rows]


@dispatch(pd.DataFrame, str)
def get_values(df: pd.DataFrame, col: str):
    return df[col]


@dispatch(pd.DataFrame, list)
def get_values(df: pd.DataFrame, cols: List[str]):
    return df[cols]

# %% [markdown]
#                                                                                                                                                                           ### BioRvix Service

# %%
#from tqdm import tqdm_notebook, tnrange

#variables
#https://api.biorxiv.org/pubs/biorvix/2018-08-21/2018-08-28
#https://api.biorxiv.org/details/biorxiv/10.1101/759530
#https://api.biorxiv.org/details/biorvix/10.1101/759530
base_url: str = 'https://api.biorxiv.org'
query_type: str = 'details'
server: str = 'biorxiv'
url: str = f'{base_url}/{query_type}/{server}'
path: str = f'prepub-{query_type}-{server}-{datetime.now()}'
step = 100
#doi = ['10.1101/856302']
doi = pubs_df.DOI
prepub_df = None

'''
for item in tqdm_notebook(range(0, total, step), desc='get_prepublish_data',
                 total=math.ceil(total/step)):
    #time.sleep(0.005)
    results = get_data(None,
                       url,
                       doi[item:item+step])
    tmp = list(results)
    prepub_df = query_to_df([r for r in tmp],
                            ["doi", "title", "authors", "author_corresponding", "author_corresponding_institution", "date", "version", "type", "category", "published"],
                            range(item, item + (len(tmp) * step), step),
#                            range(item, (item + ((len(tmp[counter]) - 1) * step)) * 10, step),
                            ["DOI", "Title", "Authors", "Corresponding_Authors", "Institution", "Date", "Version", "Type", "Category", "pub_DOI"], False)
    #prepub_df = create_prepublish_df(prepub_df)
    prepub_df.to_parquet(pathlib.Path(f'{path}/{datetime.utcnow().timestamp()}.parquet'))
'''

#create directory
pathlib.Path(path).mkdir(parents=True, exist_ok=True)
total = len(doi)
args = [(path, url, doi, item, step, True) for item in range(0, total, step)]
#print(f'args: {len(args)}\n{args}')
print(url, f'total doi: {total} iter: {total / step}')
#tq.thread_map(lambda p: process_doi_data(*p), args, desc='process_doi_data', max_workers=5, total=len(args))
tq.thread_map(lambda p: process_doi_data(*p), args, desc='process_doi_data', total=len(args))

# %%
prepub_df = create_prepublish_df(pd.read_parquet(pathlib.Path(path)))

prepub_df

# %%
print('Published data:\n',
      [(name, pubs_df[name].isnull().sum()) for name in pubs_df.columns if pubs_df[name].isnull().values.any()])
print('Prepublish data:\n',
      [(name, prepub_df[name].isnull().sum()) for name in prepub_df.columns if prepub_df[name].isnull().values.any()])

# %%
combined_df = pd.merge(pubs_df, prepub_df, how="outer",
                       on=['DOI', 'Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Category',
                           'Num_of_Authors', 'pub_DOI'])
#combined_df = pd.merge(pubs_df,prepub_df, how="right", on=['DOI','Title', 'Authors', 'Corresponding_Authors', 'Institution', 'Category', 'Num_of_Authors'])
combined_df['Time_month'] = (combined_df['Published_Date'] - combined_df['Preprint_Date']) / np.timedelta64(1, 'M')
combined_df['Keep'] = combined_df.Published_Date > combined_df.Preprint_Date
#ref = combined_df.set_index(['pub_DOI'], inplace=False)
combined_df.head(1)
#display(combined_df.groupby('DOI').count())

# %%
print([(index, value) for index, value in enumerate(combined_df.groupby(['DOI'])['Time_month'])])

# %%
# checking for NA
print([(name, combined_df[name].isnull().sum()) for name in combined_df.columns if
       combined_df[name].isnull().values.any()])
print([(name, combined_df.groupby([name], dropna=False).size) for name in combined_df.columns if
       (combined_df.groupby([name], dropna=False)[name].count() > 0).any()])
print([(name, combined_df.groupby([name], dropna=True).size) for name in combined_df.columns if
       (combined_df.groupby([name], dropna=False)[name].count() > 0).any()])

# %%
##%%capture cap
display(prepub_df.shape, pubs_df.shape, combined_df.shape,
        combined_df.groupby(['pub_DOI'], as_index=True).count().shape)
#test = combined_df.groupby(['DOI', 'pub_DOI', 'Category', 'Institution', 'Corresponding_Authors', 'Journal', 'Preprint_Date', 'Published_Date', 'Authors', 'Num_of_Authors', 'Title', 'Date', 'Version'])
test = combined_df.groupby(['DOI'], as_index=True)
#display(test.iloc[test.Title.nunique().ne(1),:])
#display(test.Title.nunique().ne(1).index)
#display(test.Title.nunique().ne(1))
#key = test.Title.nunique().ne(1)
#display(ref.index.isin(key))
#display(ref[ref.index.isin(key)])
#display(test.Title.nunique().ne(1).shape)
#test.Title.indices.
#display(test.Title.indices)
#df.at only get signal value so need to use list comprehension to get multiple columns in a particular row
#print(test.Title.indices['10.1128/IAI.00353-19'])
#display(combined_df .iloc[[1826, 1827]])
#display(combined_df)
combined_df.groupby(['pub_DOI'], as_index=False).Title.unique()

# %%
combined_df.groupby(['Category', 'Keep'], as_index=True).Time_month.describe()

# %% [markdown]
# **NB:** There are some issues with the above table since there are 29 publications that have more than one enteries.

# %%
df = combined_df.loc[combined_df.reset_index().groupby(['pub_DOI'])['Time_month'].idxmax()]

# %%
display(df.groupby(['Category']).Time_month.describe())

# %%
combined_df.groupby(['Institution'], as_index=True).pub_DOI.describe().to_csv("general.csv")

# %%
combined_df.groupby(['Institution', 'Category'], as_index=True).Time_month.describe()

# %%
reduce_df = combined_df[combined_df.Keep == True]
reduce_df.groupby(['Category', 'Keep'], as_index=True).Time_month.describe()

# %%
print(pubs_df.shape)
print(prepub_df.shape)
print(test.count().shape)
print((test.Title.nunique() - 1).shape)

# %%
test.filter(lambda x: x['Title'].nunique() > 1).to_csv('title-change.csv')
prepub_df.to_csv('pre&pub-data.csv')
pubs_df.to_csv('pub_data.csv')
